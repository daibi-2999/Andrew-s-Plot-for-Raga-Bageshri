# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga bageshri.csv")

# %%
print(df.head())
# Out:
#        Song Name   P(S)=X1  P(r )=X2   P(R)=X3   P(g)=X4  P(G)=X5   P(M)=X6  \
# 0  Raag Bageshri  0.313953         0  0.104651  0.081395        0  0.139535
#
#    P(m)=X7  P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=X12
# 0        0        0        0  0.186047  0.174419         0

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="Green")
